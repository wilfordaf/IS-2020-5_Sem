# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Задание 0

# %% [markdown]
# Для всех  заданий будем использовать обезличенные транзакционные банковские данные. Для этого считайте в переменные **tr_mcc_codes, tr_types, transactions и gender_train** из одноимённых таблиц из папки [data](https://drive.google.com/drive/folders/1YAMe7MiTxA-RSSd8Ex2p-L0Dspe6Gs4L).
#
# Для таблицы transactions используйте только первые n=1000000 строк. При чтении файлов обратите внимание на разделители внутри каждого из файлов - они могут различаться!

# %% [markdown]
# ###  Описание данных
# #### Таблица ```transactions.csv```
# ##### Описание
# Таблица содержит историю транзакций клиентов банка за один год и три месяца.
#
# ##### Формат данных
#
# ```
# customer_id,tr_datetime,mcc_code,tr_type,amount,term_id
# 111111,15 01:40:52,1111,1000,-5224,111111
# 111112,15 15:18:32,3333,2000,-100,11122233
# ...
# ```
# ##### Описание полей
#
#  - ```customer_id``` — идентификатор клиента;
#  - ```tr_datetime``` — день и время совершения транзакции (дни нумеруются с начала данных);
#  - ```mcc_code``` — mcc-код транзакции;
#  - ```tr_type``` — тип транзакции;
#  - ```amount``` — сумма транзакции в условных единицах со знаком; ```+``` — начисление средств клиенту (приходная транзакция), ```-``` — списание средств (расходная транзакция);
#  - ```term_id``` — идентификатор терминала;
#
#
# #### Таблица ```gender_train.csv```
#
# ##### Описание
# Данная таблица содержит информацию по полу для части клиентов, для которых он известен. Для остальных клиентов пол неизвестен.
#
# ##### Формат данных
# ```
# customer_id,gender
# 111111,0
# 111112,1
# ...
# ```
#
# ##### Описание полей
#  - ```customer_id``` — идентификатор клиента;
#  - ```gender``` — пол клиента;
#
# ### Таблица ```tr_mcc_codes.csv```
#
# ##### Описание
# Данная таблица содержит описание mcc-кодов транзакций.
#
# ##### Формат данных
# ```
# mcc_code;mcc_description
# 1000;словесное описание mcc-кода 1000
# 2000;словесное описание mcc-кода 2000
# ...
# ```
#
# ##### Описание полей
#  - ```mcc_code``` – mcc-код транзакции;
#  - ```mcc_description``` — описание mcc-кода транзакции.
#
# #### Таблица ```tr_types.csv```
#
# ##### Описание
# Данная таблица содержит описание типов транзакций.
#
# ##### Формат данных
# ```
# tr_type;tr_description
# 1000;словесное описание типа транзакции 1000
# 2000;словесное описание типа транзакции 2000
# ...
# ```
#
# ##### Описание полей
#  - ```tr_type``` – тип транзакции;
#  - ```tr_description``` — описание типа транзакции;

# %%
from google.colab import drive


drive.mount("/google_drive")
# Out:
# Mounted at /google_drive

# %%
transactions_sample_size = 10 ** 6

tr_mcc_codes = pd.read_csv(
    "/google_drive/MyDrive/Data/tr_mcc_codes.csv", 
    sep=";")

tr_types = pd.read_csv(
    "/google_drive/MyDrive/Data/tr_types.csv", 
    sep=";")

gender_train = pd.read_csv(
    "/google_drive/MyDrive/Data/gender_train.csv", 
    sep=",")


transactions = pd.read_csv(
    "/google_drive/MyDrive/Data/transactions.csv", 
    sep=",", 
    nrows=transactions_sample_size)

# %% [markdown]
# Задания 1-4 делаются без использования merge!
#
# ## Задание 1

# %% [markdown]
# 1. Для столбца tr_type датафрейма transactions выберите произвольные 1000 строк с помощью метода sample
# 2. В полученной на предыдущем этапе подвыборке найдите долю транзакций (стобец tr_description в датасете tr_types), в которой содержится подстрока 'POS' или 'ATM'

# %%
def task_1(sample_size: int) -> float:
    tr_type_sample = transactions["tr_type"].sample(n=sample_size)

    tr_types_mathing_pattern= tr_types["tr_type"][
        tr_types["tr_description"].str.contains("POS|АТМ", regex=True)]

    sample_items_matching_pattern_count = tr_type_sample.isin(
        tr_types_mathing_pattern).value_counts()[True]

    return sample_items_matching_pattern_count / sample_size


if __name__ == "__main__":
    print(f"{task_1(1000):.3f}")
# Out:
# 0.622

# %% [markdown]
# ## Задание 2

# %% [markdown]
# 1. Для столбца tr_type датафрейма transactions посчитайте частоту встречаемости всех типов транзакций tr_type в transactions.
# 2. Выведите топ-10 транзакций по частоте встречаемости (вывести для них tr_description тоже).

# %%
# transactions_sample_size == 10 ** 6
def task_2_1() -> pd.Series:
    return transactions[["tr_type"]].value_counts() / transactions_sample_size

def task_2_2(tr_type_frequency: pd.Series) -> pd.Series: 
    tr_type_top_ten = tr_type_frequency.sort_values(ascending=False).head(10)
    tr_type_top_ten_index = [int(x[0]) for x in tr_type_top_ten.index]
    return tr_type_top_ten, tr_types[tr_types["tr_type"].isin(tr_type_top_ten_index)] 



if __name__ == "__main__":
    tr_type_frequency = task_2_1()
    print(f"Task 1:\n{tr_type_frequency.to_string()}\n")

    tr_type_top_ten, tr_description_top_ten = task_2_2(tr_type_frequency)
    print(f"Task 2:\n{tr_type_top_ten}")
    print(tr_description_top_ten)
# Out:
# Task 1:
# tr_type
# 1010       0.231117
# 2010       0.151166
# 7070       0.149006
# 1110       0.137658
# 1030       0.118975
# 2370       0.049830
# 7010       0.028972
# 7030       0.026078
# 7071       0.015781
# 1100       0.015476
# 1200       0.010419
# 2330       0.009428
# 2011       0.006880
# 2371       0.006264
# 4071       0.006264
# 1210       0.005244
# 4010       0.004925
# 7031       0.003032
# 2331       0.002697
# 4051       0.002697
# 7020       0.002036
# 4011       0.001846
# 2020       0.001790
# 6110       0.001666
# 2110       0.001273
# 4110       0.001271
# 7011       0.001252
# 2320       0.001237
# 2210       0.000680
# 2440       0.000555
# 7021       0.000541
# 7074       0.000505
# 7014       0.000475
# 4210       0.000451
# 6200       0.000344
# 6100       0.000328
# 2460       0.000298
# 6010       0.000272
# 1410       0.000179
# 1310       0.000166
# 4090       0.000144
# 7034       0.000126
# 4041       0.000068
# 4031       0.000063
# 2456       0.000060
# 2021       0.000057
# 4500       0.000057
# 4097       0.000050
# 4020       0.000036
# 6210       0.000033
# 4100       0.000028
# 7024       0.000026
# 7040       0.000025
# 2100       0.000019
# 6000       0.000017
# 2340       0.000014
# 7075       0.000012
# 7035       0.000012
# 4021       0.000011
# 7041       0.000009
# 7015       0.000008
# 8145       0.000008
# 1000       0.000008
# 4200       0.000006
# 2200       0.000006
# 4061       0.000004
# 4096       0.000004
# 2446       0.000004
# 2341       0.000004
# 8146       0.000003
# 8100       0.000002
# 1510       0.000002
#
# Task 2:
# tr_type
# 1010       0.231117
# 2010       0.151166
# 7070       0.149006
# 1110       0.137658
# 1030       0.118975
# 2370       0.049830
# 7010       0.028972
# 7030       0.026078
# 7071       0.015781
# 1100       0.015476
# dtype: float64
#      tr_type                                     tr_description
# 39      7010       Взнос наличных через АТМ (в своем тер.банке)
# 47      7030  Перевод на карту (с карты) через АТМ (в предел...
# 59      7070  Перевод на карту (с карты) через Мобильный бан...
# 60      7071  Перевод на карту (с карты) через Мобильный бан...
# 98      1010                              Покупка. POS ТУ СБ РФ
# 99      1030                     Оплата услуги. Банкоматы СБ РФ
# 100     1100                                Покупка. ТУ  Россия
# 101     1110                             Покупка. POS ТУ Россия
# 106     2010              Выдача наличных в АТМ Сбербанк России
# 129     2370  Списание с карты на карту по операции <перевод...

# %% [markdown]
# ## Задание 3
# 1. В датафрейме transactions найдите клиента с максимальной суммой приходов на карту
# 2. В датафрейме transactions найдите клиента с максимальной суммой расходов по карте
# 3. Найдите модуль разницы для этих клиентов между суммой расходов и суммой приходов

# %%
def task_3_1(customers_amount_transactions: pd.Series) -> pd.Series:
    customers_replenishment_transactions = customers_amount_transactions[customers_amount_transactions["amount"] >= 0]
    customers_replenishment_sum = customers_replenishment_transactions.groupby("customer_id")["amount"].sum()
    return customers_replenishment_sum.sort_values(ascending=False).head(1)

def task_3_2(customers_amount_transactions: pd.Series) -> pd.Series:
    customers_withdrawal_transactions = customers_amount_transactions[customers_amount_transactions["amount"] < 0]
    customers_withdrawal_sum = customers_withdrawal_transactions.groupby("customer_id")["amount"].sum()
    return customers_withdrawal_sum.sort_values().head(1)

def task_3_3(top_one_replenishment_customer: pd.Series, top_one_withdrawal_customer: pd.Series) -> float:
    return np.abs(top_one_replenishment_customer.item() - top_one_withdrawal_customer.item())


if __name__ == "__main__":
    customers_amount_transactions = transactions[["customer_id", "amount"]]

    top_one_replenishment_customer = task_3_1(customers_amount_transactions)
    print(top_one_replenishment_customer.to_string(), end="\n\n")

    top_one_withdrawal_customer = task_3_2(customers_amount_transactions)
    print(top_one_withdrawal_customer.to_string(), end="\n\n")

    print(f"Abs of difference: {task_3_3(top_one_replenishment_customer, top_one_withdrawal_customer)}")
# Out:
# customer_id
# 70780820    1.248115e+09
#
# customer_id
# 70780820   -1.249952e+09
#
# Abs of difference: 2498067091.6

# %% [markdown]
# ## Задание 4
# 1. Найдите среднее арифметическое и медиану по amount по всем типам транзакций из топ 10 из задания 2
# 1. Найдите среднее арифметическое и медиану по amount по всем типам транзакций для клиентов из задания 3

# %%
def calculate_arithmetic_mean_and_median(data: pd.DataFrame) -> pd.DataFrame:
    arithmetic_mean = data.groupby("tr_type").mean()
    median = data.groupby("tr_type").median()

    return pd.concat(
        [arithmetic_mean, median], 
        axis=1, 
        keys=["Arithmetic mean", "Median"])

# tr_type_top_ten - ["tr_type", "frequency"]
def task_4_1() -> pd.DataFrame:
    top_ten_frequent_tr_types = [int(x[0]) for x in tr_type_top_ten.index]
    tr_with_frequent_types = transactions[transactions["tr_type"].isin(top_ten_frequent_tr_types)][["tr_type", "amount"]]

    return calculate_arithmetic_mean_and_median(tr_with_frequent_types)

def task_4_2() -> pd.DataFrame:
    top_one_replenishment_customer_id = top_one_replenishment_customer.index[0]
    top_one_withdrawal_customer_id = top_one_withdrawal_customer.index[0]
    if top_one_replenishment_customer_id == top_one_withdrawal_customer_id:
        customers_transactions = transactions[transactions["customer_id"] == top_one_replenishment_customer_id][["tr_type", "amount"]]

    return calculate_arithmetic_mean_and_median(customers_transactions)

if __name__ == "__main__":
    print(f"Task 1:\n{task_4_1()}\n")
    print(f"Task 2:\n{task_4_2()}")
# Out:
# Task 1:
#         Arithmetic mean     Median
#                  amount     amount
# tr_type
# 1010      -19784.748640   -7411.52
# 1030       -5320.980222   -2245.92
# 1100      -44061.827262  -10188.26
# 1110      -32119.330371  -11207.57
# 2010     -136077.629325  -44918.32
# 2370     -205418.249032  -44918.32
# 7010      276391.789596  112295.79
# 7030       86104.332909   13951.52
# 7070       65569.831700   11319.42
# 7071       66806.826623    3593.47
#
# Task 2:
#         Arithmetic mean       Median
#                  amount       amount
# tr_type
# 2010      -2.941056e+06 -3368873.660
# 2330      -2.382398e+06 -2245915.770
# 2370      -2.218505e+06 -2245915.770
# 6110       1.756293e+04    10028.010
# 7020       1.465129e+04    10319.985
# 7021       2.850067e+04    28500.670
# 7030       1.406196e+04     8848.910
# 7031       1.921036e+04    12992.620
# 7034       1.430648e+04    14306.480
# 7040       2.153833e+04    14396.320
# 7070       1.384821e+04     8714.150
# 7071       1.860057e+04    12543.440
# 7074       2.281159e+04     9387.930

# %% [markdown]
# ## Подготовка для заданий 5-8

# %% [markdown]
# *Из заданий 5-8 нужно выполнить минимум два любых*
#
# Соедините transactions с всеми остальными таблицами (tr_mcc_codes, tr_types, gender_train). Причём с gender_train необходимо смёрджиться с помощью left join, а с оставшимися датафреймами - через inner.
# После получения результата таблицы gender_train, tr_types, tr_mcc_codes можно удалить. В результате соединения датафреймов должно получиться 999584 строки.

# %%
transactions_merged = pd.merge(transactions, gender_train, how="left")
transactions_merged = pd.merge(transactions_merged, tr_mcc_codes, how="inner")
transactions_merged = pd.merge(transactions_merged, tr_types, how="inner")
transactions_merged.shape
# Out:
# (999584, 9)

# %% [markdown]
# ## Задание 5

# %% [markdown]
# 1. Определите модуль разницы между средними тратами женщин и мужчин (трата - отрицательное значение amount).
# 2. Определите модуль разницы между средними поступлениями у мужчин и женщин
#
# Обратите внимание, что для вычисления модуля разности точных знаний о том,
# какой класc относится к мужчинам, а какой - к женщинам, не требуется.

# %%
def calculate_abs_by_grouped_transactions(transactions: pd.Series) -> float:
    return np.abs(transactions[0] - transactions[1])

def task_5_1() -> pd.Series:
    spending_transactions = transactions_merged[transactions_merged["amount"] < 0]
    return calculate_abs_by_grouped_transactions(
        spending_transactions.groupby("gender")["amount"].mean())

def task_5_2() -> pd.Series:
    flow_transactions = transactions_merged[transactions_merged["amount"] >= 0]
    return calculate_abs_by_grouped_transactions(
        flow_transactions.groupby("gender")["amount"].mean())
  

if __name__ == "__main__":
    print(f"Task 5.1: {task_5_1():.3f}")
    print(f"Task 5.2: {task_5_2():.3f}")
# Out:
# Task 5.1: 32718.055
# Task 5.2: 63366.571

# %% [markdown]
# ## Задание 6

# %% [markdown]
# 1. По всем типам транзакций рассчитайте максимальную сумму прихода на карту (из строго положительных сумм по столбцу amount) отдельно для мужчин и женщин (назовите ее "max_income"). Оставьте по 10 типов транзакций для мужчин и для женщин, наименьших среди всех типов транзакций по полученным значениям "max_income".
# 2. Выделите среди них те типы транзакций, которые встречаются одновременно и у мужчин, и у женщин

# %%
def task_6_1(gender: int) -> pd.Series:
    if gender not in [0, 1]:
        raise ValueError("Unknown gender")

    flow_transactions = transactions_merged[transactions_merged["amount"] > 0]

    gender_flow_tr = flow_transactions[flow_transactions["gender"] == gender]

    max_flow_tr_by_gender = gender_flow_tr.groupby("tr_type")["amount"].sum()

    return max_flow_tr_by_gender.sort_values().head(10)
  
def task_6_2(flow_tr: pd.Series, other_flow_tr: pd.Series) -> list:
  return list(
      set(flow_tr.index.to_list()).intersection(other_flow_tr.index.to_list()))
  

if __name__ == "__main__":
    max_income_gender_0 = task_6_1(0)
    print(f"Task 6.1:\n\nGender 0\n{max_income_gender_0.to_string()}\n")
    max_income_gender_1 = task_6_1(1)
    print(f"Gender 1\n{max_income_gender_1.to_string()}")
    print("\nTask 6.2:\n")
    print(*task_6_2(max_income_gender_0, max_income_gender_1))
# Out:
# Task 6.1:
#
# Gender 0
# tr_type
# 4051     1122.96
# 4210     2245.92
# 4110     2245.92
# 2370     2335.75
# 7075     6737.75
# 2110    22459.16
# 1010    31532.66
# 4100    40334.88
# 2210    68315.82
# 1210    83644.87
#
# Gender 1
# tr_type
# 2020      2245.92
# 4110      4491.84
# 1010     35317.03
# 8100     64682.37
# 6000     79280.83
# 7041     87590.72
# 2370    113194.15
# 7015    121279.45
# 2110    179673.26
# 2010    224591.59
#
# Task 6.2:
#
# 2110 1010 2370 4110

# %% [markdown]
# ## Задание 7

# %% [markdown]
# 1. Найдите суммы затрат по каждой категории (mcc) для мужчин и для женщин.
# 2. Найдите топ 10 категорий с самыми большими относительными модулями разности в тратах для разных полов (в ответе должны присутствовать описания mcc кодов).

# %%
def task_7_1(gender: int) -> pd.Series:
    if gender not in [0, 1]:
        raise ValueError("Unknown gender")

    spending_transactions = transactions_merged[
        transactions_merged["amount"] <= 0]

    gender_spending_tr = spending_transactions[
        spending_transactions["gender"] == gender]

    max_spending_tr_by_gender = gender_spending_tr.groupby([
        "mcc_code", "mcc_description"])["amount"].sum()

    return max_spending_tr_by_gender

def task_7_2(mcc_list: pd.Series, other_mcc_list: pd.Series) -> pd.Series:
    mcc_merged = pd.merge(
        mcc_list.to_frame(), 
        other_mcc_list.to_frame(),
        how="inner",
        on=["mcc_code", "mcc_description"],
        suffixes=(" gender 0", " gender 1"))

    mcc_by_gender_abs_diff = np.abs(
        mcc_merged["amount gender 0"] - mcc_merged["amount gender 1"])

    return mcc_by_gender_abs_diff.sort_values(ascending=False).head(10)

if __name__ == "__main__":
    gender_0_top_ten_spending_mcc = task_7_1(0)
    print(f"Task 7.1:\n\nGender 0\n{gender_0_top_ten_spending_mcc.to_string()}\n")
    gender_1_top_ten_spending_mcc = task_7_1(1)
    print(f"Gender 1\n{gender_1_top_ten_spending_mcc.to_string()}\n")
    print("Task 7.2\n")
    print(task_7_2(gender_0_top_ten_spending_mcc, gender_1_top_ten_spending_mcc).to_string())
# Out:
# Task 7.1:
#
# Gender 0
# mcc_code  mcc_description
# 742       Ветеринарные услуги                                                                                                                                          -3.862077e+05
# 1711      Генеральные подрядчики по вентиляции, теплоснабжению, и водопроводу                                                                                          -6.748977e+05
# 1799      Подрядчики, специализированная торговля — нигде более не классифицированные                                                                                  -2.616267e+05
# 2741      Разнообразные издательства/печатное дело                                                                                                                     -2.074642e+04
# 3000      Авиалинии, авиакомпании                                                                                                                                      -7.443165e+07
# 3351      Агентства по аренде автомобилей                                                                                                                              -4.365737e+05
# 3501      Жилье — отели, мотели, курорты                                                                                                                               -3.359292e+06
# 4111      Транспортировка — пригородные и локальные сезонные транспортные средства, включая электрички                                                                 -2.251975e+06
# 4112      Пассажирские железные перевозки                                                                                                                              -3.053518e+07
# 4121      Лимузины и такси                                                                                                                                             -1.628323e+06
# 4131      Автобусные линии                                                                                                                                             -2.847649e+06
# 4214      Агентства по автотранспортным перевозкам, местные/дальные автогрузоперевозки, компании попереезду и хранению, местная доставка                               -5.120014e+05
# 4215      Услуги курьера — по воздуху и на земле, агентство по отправке грузов                                                                                         -1.361077e+06
# 4411      Круизные линии                                                                                                                                               -3.516601e+05
# 4511      Авиалинии, авиакомпании, нигде более не классифицированные                                                                                                   -4.542711e+07
# 4722      Туристические агентства и организаторы экскурсий                                                                                                             -5.046211e+07
# 4784      Дорожный и мостовой сборы, пошлины                                                                                                                           -7.600586e+05
# 4789      Услуги по транспортировке — нигде более не классифицированные                                                                                                -1.937466e+06
# 4812      Телекоммуникационное оборудование, включая продажу телефонов                                                                                                 -2.774318e+07
# 4814      Звонки с использованием телефонов, считывающих магнитную ленту                                                                                               -1.858451e+08
# 4816      Компьютерная сеть/информационные услуги                                                                                                                      -2.712450e+06
# 4829      Денежные переводы                                                                                                                                            -3.513864e+09
# 4899      Кабельные и другие платные телевизионные услуги                                                                                                              -4.268264e+05
# 4900      Коммунальные услуги — электричество, газ, санитария, вода                                                                                                    -3.399127e+07
# 5013      Поставщики грузовиков и запчастей                                                                                                                            -2.358212e+04
# 5039      Строительные материалы — нигде более не классифицированные                                                                                                   -1.187910e+05
# 5044      Офисное, фотографическое, фотокопировальное, и микрофильмирующее оборудование                                                                                -5.935057e+05
# 5045      Компьютеры, периферийное компьютерное оборудование, программное обеспечение                                                                                  -3.129744e+05
# 5047      Стоматологическое/лабороторное/медицинское/офтальмологическое стационарное оборудование и устройства                                                         -2.562590e+05
# 5065      Электрические части и оборудование                                                                                                                           -2.081402e+05
# 5072      Оборудование и сопутствующие материалы для технического обеспечения                                                                                          -1.138679e+04
# 5074      Оборудование для водопровода и отопительной системы                                                                                                          -3.062755e+05
# 5085      Промышленное оборудование — нигде более не классифицированное                                                                                                -2.717559e+04
# 5094      Драгоценные камни и металлы, часы и ювелирные изделия                                                                                                        -4.040391e+05
# 5099      Товары длительного пользования — нигде более не классифицированные                                                                                           -2.241343e+05
# 5111      Канцелярия, офисные сопутствующие товары, бумага для печатания и письма                                                                                      -7.207144e+04
# 5122      Лекарства, их распространители, аптеки                                                                                                                       -6.215511e+05
# 5131      Штучные товары, галантерея и другие текстильные товары                                                                                                       -2.933031e+05
# 5137      Мужская, женская и детская спец-одежда                                                                                                                       -3.173030e+05
# 5169      Химикалии и смежные вещества, не классифицированные ранее                                                                                                    -3.278702e+05
# 5172      Нефть и нефтепродукты                                                                                                                                        -6.270597e+04
# 5192      Книги, периодические издания и газеты                                                                                                                        -1.219533e+04
# 5193      Оборудование для выращивания растений, инвентарь для питомников и цветы                                                                                      -1.015154e+04
# 5199      Товары недлительного пользования, не классифицированные ранее                                                                                                -2.560344e+05
# 5200      Товары для дома                                                                                                                                              -3.192984e+07
# 5211      Лесо- и строительный материал                                                                                                                                -7.163894e+07
# 5231      Розничная продажа стекла, красок и обоев                                                                                                                     -2.730195e+06
# 5251      Скобяные товары в розницу                                                                                                                                    -7.849387e+06
# 5261      Садовые принадлежности (в том числе для ухода за газонами) в розницу                                                                                         -4.181245e+07
# 5300      Оптовики                                                                                                                                                     -1.065467e+07
# 5309      Беспошлинные магазины Duty Free                                                                                                                              -8.210447e+06
# 5310      Магазины, торгующие по сниженным ценам                                                                                                                       -3.517578e+05
# 5311      Универмаги                                                                                                                                                   -4.820615e+07
# 5331      Универсальные магазины                                                                                                                                       -8.847047e+07
# 5399      Различные товары общего назначения                                                                                                                           -8.217848e+06
# 5411      Бакалейные магазины, супермаркеты                                                                                                                            -5.782158e+08
# 5422      Продажа свежего и мороженого мяса                                                                                                                            -4.926800e+05
# 5441      Кондитерские                                                                                                                                                 -5.524526e+05
# 5451      Продажа молочных продуктов в розницу                                                                                                                         -3.661746e+05
# 5462      Булочные                                                                                                                                                     -4.025638e+05
# 5499      Различные продовольственные магазины — рынки, магазины со спец-ассортиментом, продажа полуфабрикатов, фирменных блюд, продажа с помощью торговых автоматов   -1.055638e+08
# 5511      Легковой и грузовой транспорт — продажа, сервис, ремонт, запчасти и лизинг                                                                                   -5.095159e+06
# 5532      Автошины                                                                                                                                                     -4.408733e+05
# 5533      Автозапчасти и аксессуары                                                                                                                                    -1.278980e+07
# 5541      Станции техобслуживания                                                                                                                                      -5.162489e+07
# 5542      Автоматизированные бензозаправки                                                                                                                             -9.581234e+04
# 5599      Продажа снегоходов                                                                                                                                           -2.820000e+06
# 5611      Мужская одежда и аксессуары, включая одежду для мальчиков                                                                                                    -8.559102e+06
# 5621      Готовая женская одежда                                                                                                                                       -4.627508e+07
# 5631      Аксессуары для женщин                                                                                                                                        -7.391764e+06
# 5641      Детская одежда, включая одежду для самых маленьких                                                                                                           -2.778109e+07
# 5651      Одежда для всей семьи                                                                                                                                        -5.916906e+07
# 5655      Спортивная одежда, одежда для верховой езды и езды на мотоцикле                                                                                              -1.343496e+07
# 5661      Обувные магазины                                                                                                                                             -8.183139e+07
# 5681      Изготовление и продажа меховых изделий                                                                                                                       -1.432288e+07
# 5691      Магазины мужской и женской одежды                                                                                                                            -1.170029e+08
# 5697      Услуги по переделке, починке и пошиву одежды                                                                                                                 -1.717227e+05
# 5699      Различные магазины одежды и аксессуаров                                                                                                                      -4.517219e+07
# 5712      Оборудование, мебель и бытовые принадлежности (кроме электрооборудования)                                                                                    -9.137320e+07
# 5713      Покрытия для пола                                                                                                                                            -6.826712e+05
# 5714      Ткани, обивочный материал, гардины и портьеры, жалюзи                                                                                                        -4.430811e+06
# 5719      Различные специализированные магазины бытовых принадлежностей                                                                                                -1.892144e+07
# 5722      Бытовое оборудование                                                                                                                                         -4.765500e+07
# 5732      Продажа электронного оборудования                                                                                                                            -3.737009e+07
# 5733      Продажа музыкальных инструментов, фортепиано, нот                                                                                                            -7.928083e+04
# 5734      Продажа компьютерного программного обеспечения                                                                                                               -2.081971e+06
# 5735      Магазины звукозаписи                                                                                                                                         -2.414766e+06
# 5811      Поставщики провизии                                                                                                                                          -2.630724e+05
# 5812      Места общественного питания, рестораны                                                                                                                       -5.787961e+07
# 5813      Бары, коктейль-бары, дискотеки, ночные клубы и таверны — места продажи алкогольных напитков                                                                  -2.668815e+06
# 5814      Рестораны, закусочные                                                                                                                                        -2.459325e+07
# 5816      Цифровые товары, игры                                                                                                                                        -4.637591e+04
# 5912      Аптеки                                                                                                                                                       -1.071868e+08
# 5921      Магазины с продажей спиртных напитков на вынос (пиво, вино и ликер)                                                                                          -1.272102e+07
# 5931      Магазины second hand, магазины б/у товаров, комиссионки                                                                                                      -6.272618e+05
# 5940      Веломагазины — продажа и обслуживание                                                                                                                        -1.257713e+05
# 5941      Магазины спорттоваров                                                                                                                                        -3.362432e+07
# 5942      Книжные магазины                                                                                                                                             -1.001704e+07
# 5943      Магазины офисных, школьных принадлежностей, канцтоваров                                                                                                      -4.641399e+06
# 5944      Магазины по продаже часов, ювелирных изделий и изделий из серебра                                                                                            -3.941117e+07
# 5945      Магазины игрушек                                                                                                                                             -2.006073e+07
# 5946      Магазины фотооборудования и фотоприборов                                                                                                                     -3.649838e+05
# 5947      Магазины открыток, подарков, новинок и сувениров                                                                                                             -7.024373e+06
# 5948      Магазины кожаных изделий, дорожных принадлежностей                                                                                                           -1.252803e+07
# 5949      Магазины ткани, ниток рукоделия, шитья                                                                                                                       -3.675211e+06
# 5950      Магазины хрусталя и изделий из стекла                                                                                                                        -9.455552e+05
# 5964      Прямой маркетинг — торговля через каталог                                                                                                                    -1.059675e+07
# 5965      Прямой маркетинг — комбинированный каталог и торговцы в розницу                                                                                              -5.959845e+05
# 5968      Прямой маркетинг — торговые точки подписки                                                                                                                   -6.830652e+05
# 5969      Прямой маркетинг — другие торговые точки прямого маркетинга (нигде более не классифицированные)                                                              -1.230411e+05
# 5970      Магазины художественных и ремесленных изделий                                                                                                                -5.256408e+04
# 5971      Галереи и художественные посредники                                                                                                                          -1.735929e+06
# 5976      Ортопедические товары                                                                                                                                        -2.887821e+05
# 5977      Магазины косметики                                                                                                                                           -7.360784e+07
# 5983      Горючее топливо — уголь, нефть, разжиженный бензин, дрова                                                                                                    -7.606992e+06
# 5992      Флористика                                                                                                                                                   -5.133781e+06
# 5993      Табачные магазины                                                                                                                                            -1.120600e+05
# 5994      Дилеры по продаже печатной продукции                                                                                                                         -1.943811e+05
# 5995      Зоомагазины                                                                                                                                                  -7.218119e+06
# 5999      Плавательные бассейны — распродажа                                                                                                                           -5.279732e+07
# 6010      Финансовые институты — снятие наличности вручную                                                                                                             -2.612731e+08
# 6011      Финансовые институты — снятие наличности автоматически                                                                                                       -4.958077e+09
# 6012      Финансовые институты — торговля и услуги                                                                                                                     -1.594637e+06
# 6051      Не-финансовые институты — иностранная валюта, денежные переводы (непередаваемые), дорожные чеки, квази-кэш                                                   -1.111047e+06
# 6211      Ценные бумаги: брокеры/дилеры                                                                                                                                -2.021325e+04
# 6300      Продажа страхования, гарантированное размещение, премии                                                                                                      -1.599873e+07
# 6536      Денежные переводы MasterCard MoneySend                                                                                                                       -9.779706e+05
# 7011      Отели, мотели, базы отдыха, сервисы бронирования                                                                                                             -7.088704e+07
# 7210      Таймшер                                                                                                                                                      -7.159081e+05
# 7216      Химчистки                                                                                                                                                    -2.776850e+05
# 7221      Фотостудии                                                                                                                                                   -7.917978e+04
# 7230      Салоты красоты и парикмахерские                                                                                                                              -2.182811e+07
# 7273      Службы знакомств                                                                                                                                             -3.951285e+04
# 7278      Сервисы по покупке/продаже                                                                                                                                   -7.110568e+04
# 7298      Центры здоровья                                                                                                                                              -1.505870e+07
# 7299      Иной сервис                                                                                                                                                  -2.112982e+06
# 7311      Рекламные услуги                                                                                                                                             -3.519383e+06
# 7372      Программирование, обработка данных, интегрированные системы, дизайн                                                                                          -4.886890e+03
# 7375      Информационные провайдеры                                                                                                                                    -2.021325e+04
# 7395      Фотостудии, фотолаборатории                                                                                                                                  -1.026383e+04
# 7399      Бизнес-сервис                                                                                                                                                -1.283126e+07
# 7523      Паркинги и гаражи                                                                                                                                            -4.985786e+05
# 7538      СТО общего назначения                                                                                                                                        -4.512681e+06
# 7542      Автомойки                                                                                                                                                    -2.855458e+05
# 7629      Ремонт бытовой техники, ремонт электроприборы                                                                                                                -2.261186e+05
# 7699      Общий ремонт                                                                                                                                                 -8.673244e+05
# 7832      Кинотеатры                                                                                                                                                   -3.287641e+06
# 7841      Видеопрокат                                                                                                                                                  -3.238612e+04
# 7922      Театральные продюсерские агентства                                                                                                                           -3.250115e+06
# 7932      Билльярд-клубы                                                                                                                                               -3.045462e+04
# 7933      Боулинг-клубы                                                                                                                                                -1.385505e+05
# 7991      Туристические аттракционы и шоу                                                                                                                              -8.721843e+05
# 7993      Принадлежности для видеоигр                                                                                                                                  -2.135417e+05
# 7994      Галереи/учреждения видеоигр                                                                                                                                  -1.431735e+06
# 7995      Транзакции по азартным играм                                                                                                                                 -1.189100e+05
# 7996      Луна-парки, карнавалы, цирки, предсказатели будущего                                                                                                         -1.630099e+06
# 7997      Клубы — сельские клубы, членство(спортивный, отдых, спорт), частные поля для гольфа                                                                          -1.232554e+07
# 7999      Услуги отдыха, нигде ранее не классифицируемые                                                                                                               -4.867776e+06
# 8011      Доктора, нигде ранее не классифицируемые                                                                                                                     -2.370777e+06
# 8021      Дантисты, ортодонтисты                                                                                                                                       -1.448685e+07
# 8043      Оптика, оптические товары и очки                                                                                                                             -7.866589e+06
# 8062      Больницы                                                                                                                                                     -1.095471e+07
# 8071      Зубные и медицинские лаборатории                                                                                                                             -5.241723e+06
# 8099      Практикующие врачи, медицинские услуги, нигде ранее не классифицируемые                                                                                      -5.278080e+07
# 8220      Колледжи, университеты, профессиональные школы и младшие колледжи                                                                                            -1.347550e+05
# 8244      Школы — бизнес и секретарей                                                                                                                                  -1.605830e+05
# 8299      Образовательные услуги                                                                                                                                       -1.660984e+06
# 8398      Организации благотворительные и общественные службы                                                                                                          -1.683023e+06
# 8641      Ассоциации — гражданские, социальные и братские                                                                                                              -2.958152e+05
# 8699      Организации, членства, нигде ранее не классифицируемые                                                                                                       -5.211075e+05
# 8999      Профессиональные услуги, нигде ранее не классифицируемые                                                                                                     -1.943206e+07
# 9222      Штрафы                                                                                                                                                       -3.611432e+05
# 9311      Налоговые платежи                                                                                                                                            -4.061975e+05
# 9399      Правительственные услуги, нигде ранее не классифицируемые                                                                                                    -1.481390e+06
#
# Gender 1
# mcc_code  mcc_description
# 742       Ветеринарные услуги                                                                                                                                          -1.322779e+05
# 1711      Генеральные подрядчики по вентиляции, теплоснабжению, и водопроводу                                                                                          -2.062649e+05
# 1731      Подрядчики по электричеству                                                                                                                                  -1.215427e+05
# 1799      Подрядчики, специализированная торговля — нигде более не классифицированные                                                                                  -1.129258e+06
# 2741      Разнообразные издательства/печатное дело                                                                                                                     -2.212901e+05
# 3000      Авиалинии, авиакомпании                                                                                                                                      -9.795423e+07
# 3351      Агентства по аренде автомобилей                                                                                                                              -4.415920e+06
# 3501      Жилье — отели, мотели, курорты                                                                                                                               -1.359376e+07
# 4111      Транспортировка — пригородные и локальные сезонные транспортные средства, включая электрички                                                                 -2.083139e+06
# 4112      Пассажирские железные перевозки                                                                                                                              -2.714101e+07
# 4121      Лимузины и такси                                                                                                                                             -2.121488e+06
# 4131      Автобусные линии                                                                                                                                             -5.994515e+05
# 4214      Агентства по автотранспортным перевозкам, местные/дальные автогрузоперевозки, компании попереезду и хранению, местная доставка                               -1.108202e+05
# 4215      Услуги курьера — по воздуху и на земле, агентство по отправке грузов                                                                                         -8.681610e+05
# 4411      Круизные линии                                                                                                                                               -1.256933e+06
# 4511      Авиалинии, авиакомпании, нигде более не классифицированные                                                                                                   -7.209755e+07
# 4722      Туристические агентства и организаторы экскурсий                                                                                                             -5.403518e+07
# 4784      Дорожный и мостовой сборы, пошлины                                                                                                                           -5.638644e+05
# 4789      Услуги по транспортировке — нигде более не классифицированные                                                                                                -1.639900e+06
# 4812      Телекоммуникационное оборудование, включая продажу телефонов                                                                                                 -3.040232e+07
# 4814      Звонки с использованием телефонов, считывающих магнитную ленту                                                                                               -1.737905e+08
# 4816      Компьютерная сеть/информационные услуги                                                                                                                      -5.880591e+06
# 4829      Денежные переводы                                                                                                                                            -6.013017e+09
# 4899      Кабельные и другие платные телевизионные услуги                                                                                                              -2.088049e+06
# 4900      Коммунальные услуги — электричество, газ, санитария, вода                                                                                                    -3.548414e+07
# 5013      Поставщики грузовиков и запчастей                                                                                                                            -1.407920e+06
# 5039      Строительные материалы — нигде более не классифицированные                                                                                                   -5.966253e+06
# 5044      Офисное, фотографическое, фотокопировальное, и микрофильмирующее оборудование                                                                                -1.724763e+06
# 5045      Компьютеры, периферийное компьютерное оборудование, программное обеспечение                                                                                  -6.178570e+05
# 5047      Стоматологическое/лабороторное/медицинское/офтальмологическое стационарное оборудование и устройства                                                         -1.613466e+05
# 5065      Электрические части и оборудование                                                                                                                           -1.371563e+06
# 5072      Оборудование и сопутствующие материалы для технического обеспечения                                                                                          -6.474155e+05
# 5074      Оборудование для водопровода и отопительной системы                                                                                                          -1.908602e+06
# 5085      Промышленное оборудование — нигде более не классифицированное                                                                                                -1.900292e+05
# 5094      Драгоценные камни и металлы, часы и ювелирные изделия                                                                                                        -9.456520e+05
# 5099      Товары длительного пользования — нигде более не классифицированные                                                                                           -4.876092e+05
# 5111      Канцелярия, офисные сопутствующие товары, бумага для печатания и письма                                                                                      -3.221180e+05
# 5122      Лекарства, их распространители, аптеки                                                                                                                       -3.768656e+05
# 5137      Мужская, женская и детская спец-одежда                                                                                                                       -2.477919e+05
# 5169      Химикалии и смежные вещества, не классифицированные ранее                                                                                                    -6.530645e+05
# 5172      Нефть и нефтепродукты                                                                                                                                        -9.239698e+04
# 5192      Книги, периодические издания и газеты                                                                                                                        -7.472162e+04
# 5193      Оборудование для выращивания растений, инвентарь для питомников и цветы                                                                                      -1.049180e+06
# 5199      Товары недлительного пользования, не классифицированные ранее                                                                                                -3.723055e+05
# 5200      Товары для дома                                                                                                                                              -2.627852e+07
# 5211      Лесо- и строительный материал                                                                                                                                -7.614346e+07
# 5231      Розничная продажа стекла, красок и обоев                                                                                                                     -3.006593e+06
# 5251      Скобяные товары в розницу                                                                                                                                    -1.390074e+07
# 5261      Садовые принадлежности (в том числе для ухода за газонами) в розницу                                                                                         -5.255557e+07
# 5300      Оптовики                                                                                                                                                     -2.105723e+07
# 5309      Беспошлинные магазины Duty Free                                                                                                                              -8.176306e+06
# 5311      Универмаги                                                                                                                                                   -7.083970e+07
# 5331      Универсальные магазины                                                                                                                                       -7.450471e+07
# 5399      Различные товары общего назначения                                                                                                                           -9.517171e+06
# 5411      Бакалейные магазины, супермаркеты                                                                                                                            -6.008061e+08
# 5422      Продажа свежего и мороженого мяса                                                                                                                            -8.425820e+05
# 5441      Кондитерские                                                                                                                                                 -3.416103e+05
# 5451      Продажа молочных продуктов в розницу                                                                                                                         -5.699123e+05
# 5462      Булочные                                                                                                                                                     -2.016473e+05
# 5499      Различные продовольственные магазины — рынки, магазины со спец-ассортиментом, продажа полуфабрикатов, фирменных блюд, продажа с помощью торговых автоматов   -1.067103e+08
# 5511      Легковой и грузовой транспорт — продажа, сервис, ремонт, запчасти и лизинг                                                                                   -7.862393e+07
# 5532      Автошины                                                                                                                                                     -4.586583e+06
# 5533      Автозапчасти и аксессуары                                                                                                                                    -5.512787e+07
# 5541      Станции техобслуживания                                                                                                                                      -2.070574e+08
# 5542      Автоматизированные бензозаправки                                                                                                                             -2.406522e+06
# 5571      Продажа мотоциклов                                                                                                                                           -8.645437e+05
# 5599      Продажа снегоходов                                                                                                                                           -1.742575e+06
# 5611      Мужская одежда и аксессуары, включая одежду для мальчиков                                                                                                    -1.357865e+07
# 5621      Готовая женская одежда                                                                                                                                       -8.230822e+06
# 5631      Аксессуары для женщин                                                                                                                                        -2.417992e+06
# 5641      Детская одежда, включая одежду для самых маленьких                                                                                                           -2.826958e+07
# 5651      Одежда для всей семьи                                                                                                                                        -3.407578e+07
# 5655      Спортивная одежда, одежда для верховой езды и езды на мотоцикле                                                                                              -1.106615e+07
# 5661      Обувные магазины                                                                                                                                             -4.367668e+07
# 5681      Изготовление и продажа меховых изделий                                                                                                                       -1.872896e+07
# 5691      Магазины мужской и женской одежды                                                                                                                            -8.393060e+07
# 5699      Различные магазины одежды и аксессуаров                                                                                                                      -2.359801e+07
# 5712      Оборудование, мебель и бытовые принадлежности (кроме электрооборудования)                                                                                    -6.060797e+07
# 5713      Покрытия для пола                                                                                                                                            -8.882974e+05
# 5714      Ткани, обивочный материал, гардины и портьеры, жалюзи                                                                                                        -1.010402e+06
# 5719      Различные специализированные магазины бытовых принадлежностей                                                                                                -2.486236e+07
# 5722      Бытовое оборудование                                                                                                                                         -8.372386e+07
# 5732      Продажа электронного оборудования                                                                                                                            -6.830488e+07
# 5733      Продажа музыкальных инструментов, фортепиано, нот                                                                                                            -1.443988e+06
# 5734      Продажа компьютерного программного обеспечения                                                                                                               -6.609818e+06
# 5735      Магазины звукозаписи                                                                                                                                         -4.765448e+06
# 5811      Поставщики провизии                                                                                                                                          -6.527069e+05
# 5812      Места общественного питания, рестораны                                                                                                                       -1.282582e+08
# 5813      Бары, коктейль-бары, дискотеки, ночные клубы и таверны — места продажи алкогольных напитков                                                                  -8.884762e+06
# ...
# 5940      Веломагазины — продажа и обслуживание                                                                                                                        -6.715288e+04
# 5941      Магазины спорттоваров                                                                                                                                        -4.702436e+07
# 5942      Книжные магазины                                                                                                                                             -6.403030e+06
# 5943      Магазины офисных, школьных принадлежностей, канцтоваров                                                                                                      -2.975926e+06
# 5944      Магазины по продаже часов, ювелирных изделий и изделий из серебра                                                                                            -6.993287e+07
# 5945      Магазины игрушек                                                                                                                                             -1.644917e+07
# 5946      Магазины фотооборудования и фотоприборов                                                                                                                     -9.354483e+06
# 5947      Магазины открыток, подарков, новинок и сувениров                                                                                                             -4.852480e+06
# 5948      Магазины кожаных изделий, дорожных принадлежностей                                                                                                           -1.569953e+07
# 5949      Магазины ткани, ниток рукоделия, шитья                                                                                                                       -1.090441e+06
# 5950      Магазины хрусталя и изделий из стекла                                                                                                                        -2.351875e+06
# 5964      Прямой маркетинг — торговля через каталог                                                                                                                    -1.247600e+07
# 5967      Прямой маркетинг — входящий телемаркетинг                                                                                                                    -1.931533e+04
# 5968      Прямой маркетинг — торговые точки подписки                                                                                                                   -2.040255e+05
# 5969      Прямой маркетинг — другие торговые точки прямого маркетинга (нигде более не классифицированные)                                                              -1.674004e+06
# 5970      Магазины художественных и ремесленных изделий                                                                                                                -3.142101e+05
# 5971      Галереи и художественные посредники                                                                                                                          -5.290306e+05
# 5976      Ортопедические товары                                                                                                                                        -1.846846e+05
# 5977      Магазины косметики                                                                                                                                           -3.119022e+07
# 5983      Горючее топливо — уголь, нефть, разжиженный бензин, дрова                                                                                                    -1.849631e+07
# 5992      Флористика                                                                                                                                                   -7.891735e+06
# 5993      Табачные магазины                                                                                                                                            -1.147373e+05
# 5994      Дилеры по продаже печатной продукции                                                                                                                         -2.486018e+05
# 5995      Зоомагазины                                                                                                                                                  -7.061154e+06
# 5999      Плавательные бассейны — распродажа                                                                                                                           -6.972481e+07
# 6010      Финансовые институты — снятие наличности вручную                                                                                                             -4.821311e+08
# 6011      Финансовые институты — снятие наличности автоматически                                                                                                       -8.043939e+09
# 6012      Финансовые институты — торговля и услуги                                                                                                                     -1.823589e+06
# 6051      Не-финансовые институты — иностранная валюта, денежные переводы (непередаваемые), дорожные чеки, квази-кэш                                                   -6.861737e+06
# 6211      Ценные бумаги: брокеры/дилеры                                                                                                                                -1.209976e+07
# 6300      Продажа страхования, гарантированное размещение, премии                                                                                                      -2.468041e+07
# 6536      Денежные переводы MasterCard MoneySend                                                                                                                       -6.911979e+06
# 7011      Отели, мотели, базы отдыха, сервисы бронирования                                                                                                             -9.955502e+07
# 7210      Таймшер                                                                                                                                                      -6.607485e+04
# 7216      Химчистки                                                                                                                                                    -4.057292e+05
# 7221      Фотостудии                                                                                                                                                   -2.242884e+05
# 7230      Салоты красоты и парикмахерские                                                                                                                              -2.757304e+06
# 7273      Службы знакомств                                                                                                                                             -1.217601e+05
# 7298      Центры здоровья                                                                                                                                              -6.197195e+06
# 7299      Иной сервис                                                                                                                                                  -1.105284e+06
# 7311      Рекламные услуги                                                                                                                                             -2.675609e+06
# 7338      Услуги копировальных центров                                                                                                                                 -8.431953e+04
# 7372      Программирование, обработка данных, интегрированные системы, дизайн                                                                                          -2.042850e+06
# 7375      Информационные провайдеры                                                                                                                                    -3.023677e+04
# 7395      Фотостудии, фотолаборатории                                                                                                                                  -3.163934e+05
# 7399      Бизнес-сервис                                                                                                                                                -8.297949e+06
# 7512      Прокат автомобилей                                                                                                                                           -4.217942e+06
# 7523      Паркинги и гаражи                                                                                                                                            -9.650154e+05
# 7538      СТО общего назначения                                                                                                                                        -1.903257e+07
# 7542      Автомойки                                                                                                                                                    -1.773452e+06
# 7629      Ремонт бытовой техники, ремонт электроприборы                                                                                                                -1.194827e+05
# 7699      Общий ремонт                                                                                                                                                 -9.907276e+05
# 7829      Производство и дистрибуция видеофильмов                                                                                                                      -1.343058e+04
# 7832      Кинотеатры                                                                                                                                                   -5.915344e+06
# 7841      Видеопрокат                                                                                                                                                  -1.261531e+05
# 7922      Театральные продюсерские агентства                                                                                                                           -6.058160e+06
# 7932      Билльярд-клубы                                                                                                                                               -4.615132e+04
# 7933      Боулинг-клубы                                                                                                                                                -1.800551e+05
# 7991      Туристические аттракционы и шоу                                                                                                                              -1.059942e+06
# 7993      Принадлежности для видеоигр                                                                                                                                  -1.270921e+06
# 7994      Галереи/учреждения видеоигр                                                                                                                                  -2.853800e+06
# 7995      Транзакции по азартным играм                                                                                                                                 -4.091455e+07
# 7996      Луна-парки, карнавалы, цирки, предсказатели будущего                                                                                                         -1.070179e+06
# 7997      Клубы — сельские клубы, членство(спортивный, отдых, спорт), частные поля для гольфа                                                                          -9.325036e+06
# 7999      Услуги отдыха, нигде ранее не классифицируемые                                                                                                               -8.244461e+06
# 8011      Доктора, нигде ранее не классифицируемые                                                                                                                     -1.731067e+07
# 8021      Дантисты, ортодонтисты                                                                                                                                       -1.495105e+07
# 8043      Оптика, оптические товары и очки                                                                                                                             -1.119061e+07
# 8062      Больницы                                                                                                                                                     -1.572009e+05
# 8071      Зубные и медицинские лаборатории                                                                                                                             -5.038712e+05
# 8099      Практикующие врачи, медицинские услуги, нигде ранее не классифицируемые                                                                                      -2.971261e+07
# 8220      Колледжи, университеты, профессиональные школы и младшие колледжи                                                                                            -3.651915e+05
# 8244      Школы — бизнес и секретарей                                                                                                                                  -3.571006e+04
# 8299      Образовательные услуги                                                                                                                                       -4.665837e+06
# 8398      Организации благотворительные и общественные службы                                                                                                          -5.688880e+03
# 8641      Ассоциации — гражданские, социальные и братские                                                                                                              -2.156206e+06
# 8699      Организации, членства, нигде ранее не классифицируемые                                                                                                       -4.441831e+05
# 8999      Профессиональные услуги, нигде ранее не классифицируемые                                                                                                     -2.864335e+07
# 9222      Штрафы                                                                                                                                                       -9.882052e+05
# 9311      Налоговые платежи                                                                                                                                            -3.732712e+05
# 9399      Правительственные услуги, нигде ранее не классифицируемые                                                                                                    -1.810821e+06
# 9402      Почтовые услуги — только правительство                                                                                                                       -4.581670e+03
#
# Task 7.2
#
# mcc_code  mcc_description
# 6011      Финансовые институты — снятие наличности автоматически                        3.085862e+09
# 4829      Денежные переводы                                                             2.499153e+09
# 6010      Финансовые институты — снятие наличности вручную                              2.208580e+08
# 5541      Станции техобслуживания                                                       1.554326e+08
# 5511      Легковой и грузовой транспорт — продажа, сервис, ремонт, запчасти и лизинг    7.352877e+07
# 5812      Места общественного питания, рестораны                                        7.037856e+07
# 5977      Магазины косметики                                                            4.241762e+07
# 5533      Автозапчасти и аксессуары                                                     4.233808e+07
# 7995      Транзакции по азартным играм                                                  4.079564e+07
# 5661      Обувные магазины                                                              3.815470e+07

# %% [markdown]
# ## Задание 8

# %% [markdown]
# 1. Из поля tr_datetime выделите час tr_hour, в который произошла транзакция, как первые 2 цифры до ":". (\**)
# 2. Посчитайте количество транзакций с amount<0 в ночное время для мужчин и женщин. Ночное время - это примерно 00-06 часов.

# %%
def task_8_1() -> pd.DataFrame:
    transactions_merged[["tr_day", "tr_time"]] = transactions_merged[
        "tr_datetime"].str.split(" ", expand=True)

    transactions_merged[
        ["tr_hour", "tr_minute", "tr_second"]] = transactions_merged["tr_time"].str.split(":", expand=True)

    return transactions_merged[["tr_hour", "gender", "amount"]]
  
def task_8_2(transactions: pd.DataFrame, gender: int) -> int:
    if gender not in [0, 1]:
        raise ValueError("Unknown gender")

    spending_night_transactions = transactions[
        (transactions["gender"] == gender) & 
        (transactions["amount"] < 0) & 
        (transactions["tr_hour"].astype(int) <= 6)] 

    return spending_night_transactions.groupby("gender").count().at[gender, "amount"]


if __name__ == "__main__":
    tr_hour_gender_amount = task_8_1()
    print(f"Task 8.1:\n\n{tr_hour_gender_amount['tr_hour']}\n")
    print(f"Task 8.2:\n\nGender 0\n{task_8_2(tr_hour_gender_amount, 0)}\n")
    print(f"Gender 1\n{task_8_2(tr_hour_gender_amount, 1)}")
# Out:
# Task 8.1:
#
# 0         10
# 1         07
# 2         07
# 3         08
# 4         14
#           ..
# 999579    23
# 999580    19
# 999581    22
# 999582    23
# 999583    23
# Name: tr_hour, Length: 999584, dtype: object
#
# Task 8.2:
#
# Gender 0
# 43510
#
# Gender 1
# 46694

# %% [markdown]
# # Задание на защиту:

# %% [markdown]
# 1. По каждой категории найдите сумму трат в ночное время и в остальное время. Найдите соотношение одного к другому.
# 2. Выведите список 10 категорий с описаниями, упорядоченных по убываний отношения ночных трат к остальным тратам.

# %%
def defence_task_1() -> pd.Series:
    transactions_merged[["tr_day", "tr_time"]] = transactions_merged[
        "tr_datetime"].str.split(" ", expand=True)

    transactions_merged[
        ["tr_hour", "tr_minute", "tr_second"]] = transactions_merged["tr_time"].str.split(":", expand=True).astype(int)

    transactions_aggregated = transactions_merged[["tr_hour", "gender", "amount", "mcc_code", "mcc_description"]]
    mcc_spending_night = transactions_aggregated.query('amount < 0 and tr_hour <= 6').\
                                                groupby(["mcc_code", "mcc_description"]).amount.sum()

    mcc_spending_other = transactions_aggregated.query('amount < 0 and 6 < tr_hour').\
                                                groupby(["mcc_code", "mcc_description"]).amount.sum()

    return mcc_spending_night / mcc_spending_other

def defence_task_2(mcc_code_night_ratio: pd.Series):
    return mcc_code_night_ratio.sort_values(ascending=False).head(10)

if __name__ == "__main__":
    mcc_code_night_ratio = defence_task_1()
    print(f"Defence task 1:\n{mcc_code_night_ratio}\n")
    print(f"Defence task 2:\n{defence_task_2(mcc_code_night_ratio)}")
# Out:
# Defence task 1:
# mcc_code  mcc_description
# 742       Ветеринарные услуги                                                             2.378160
# 1711      Генеральные подрядчики по вентиляции, теплоснабжению, и водопроводу             1.200619
# 1731      Подрядчики по электричеству                                                     0.083802
# 1799      Подрядчики, специализированная торговля — нигде более не классифицированные     0.063783
# 2741      Разнообразные издательства/печатное дело                                       40.798510
#                                                                                            ...
# 9211      Судовые выплаты, включая алименты и детскую поддержку                                NaN
# 9222      Штрафы                                                                          0.777621
# 9311      Налоговые платежи                                                               9.968038
# 9399      Правительственные услуги, нигде ранее не классифицируемые                       0.930727
# 9402      Почтовые услуги — только правительство                                          7.202492
# Name: amount, Length: 184, dtype: float64
#
# Defence task 2:
# mcc_code  mcc_description
# 5964      Прямой маркетинг — торговля через каталог                                                                     628.680201
# 5969      Прямой маркетинг — другие торговые точки прямого маркетинга (нигде более не классифицированные)               371.691992
# 5735      Магазины звукозаписи                                                                                          284.672318
# 5310      Магазины, торгующие по сниженным ценам                                                                        258.007707
# 8062      Больницы                                                                                                      246.541401
# 5970      Магазины художественных и ремесленных изделий                                                                 167.493188
# 5045      Компьютеры, периферийное компьютерное оборудование, программное обеспечение                                    90.646826
# 6211      Ценные бумаги: брокеры/дилеры                                                                                  77.531165
# 6051      Не-финансовые институты — иностранная валюта, денежные переводы (непередаваемые), дорожные чеки, квази-кэш     55.382357
# 2741      Разнообразные издательства/печатное дело                                                                       40.798510
# Name: amount, dtype: float64
